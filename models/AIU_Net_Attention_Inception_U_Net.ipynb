# %% [markdown]
# # **Attention Inception U-Net for 3D Brain Tumor Segmentation**

# %%
# importing all libraries

import tensorflow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, Conv3DTranspose, MaxPooling3D, BatchNormalization, Activation, Concatenate
from tensorflow.keras.models import Model

# %%
# Convolutional blocks for the U_Net model

def conv_block(input_mat):
  num_filters = 32
  kernel_size = 3
  batch_norm = True

  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(input_mat)
  X = BatchNormalization()(X)
  X = Activation('leaky_relu')(X)

  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(X)
  X = BatchNormalization()(X)
  X = Activation('leaky_relu')(X)

  return X

# %%
# Inception blocks for the U_Net model
def inception_block(inputs):
    n_filters = 32
    conv1x1 = Conv3D(n_filters, kernel_size=1, activation='relu', padding='same')(inputs)

    conv3x3 = Conv3D(n_filters, kernel_size=1, activation='relu', padding='same')(inputs)
    conv3x3 = Conv3D(n_filters, kernel_size=3, activation='relu', padding='same')(conv3x3)

    conv5x5 = Conv3D(n_filters, kernel_size=1, activation='relu', padding='same')(inputs)
    conv5x5 = Conv3D(n_filters, kernel_size=5, activation='relu', padding='same')(conv5x5)

    maxpool3x3 = MaxPooling3D(pool_size=(3, 3, 3), strides=1, padding='same')(inputs)
    maxpool3x3 = Conv3D(n_filters, kernel_size=1, activation='relu', padding='same')(maxpool3x3)

    output = concatenate([conv1x1, conv3x3, conv5x5, maxpool3x3], axis=-1)
    return output

# %%
# Attention Module for the U_Net model
def attention_block(inputs):
    f = Conv3D(1, kernel_size=1, activation='relu', padding='same')(inputs)
    g = Conv3D(1, kernel_size=1, activation='relu', padding='same')(inputs)
    h = Conv3D(inputs.shape[-1], kernel_size=1, activation='relu', padding='same')(inputs)
    s = tf.keras.layers.multiply([f, g])
    s = tf.keras.layers.Reshape((-1,))(s)
    s = tf.keras.layers.Activation('softmax')(s)
    s = tf.keras.layers.Reshape(inputs.shape[1:-1] + (1,))(s)
    output = tf.keras.layers.multiply([h, s])
    return output

# %%
# Define 3D Attention Inception U-Net model with attention blocks only at the encoder part
# Developer can extend the inception blocks to the decoder part as per the experimental needs.

def attention_inception_unet(input_shape):
    # Input Layer
    inputs = Input(shape=input_shape)

    # Level 1 (Encoder)
    enc_attention1 = attention_block(inputs)
    enc_inception1 = inception_block(enc_attention1)
    enc_pool1 = MaxPooling3D(pool_size=(2, 2, 2))(enc_inception1)

    # Level 2
    enc_attention2 = attention_block(enc_pool1)
    enc_inception2 = inception_block(enc_attention2)
    enc_pool2 = MaxPooling3D(pool_size=(2, 2, 2))(enc_inception2)

    # Level 3
    enc_attention3 = attention_block(enc_pool2)
    enc_inception3 = inception_block(enc_attention3)
    enc_pool3 = MaxPooling3D(pool_size=(2, 2, 2))(enc_inception3)

    # Level 4
    enc_attention4 = attention_block(enc_pool3)
    enc_inception4 = inception_block(enc_attention4)
    enc_pool4 = MaxPooling3D(pool_size=(2, 2, 2))(enc_inception4)

    # Level 5 (Bridge)
    bridge_conv = Conv3D(filters=1024, kernel_size=(3, 3, 3), padding='same', activation='relu')(enc_pool4)
    bridge_inception = inception_block(bridge_conv)

    # Level 4 (Decoder)

    dec_upconv4 = Conv3DTranspose(filters=512, kernel_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(bridge_inception)
    dec_concat4 = Concatenate(axis=-1)([dec_upconv4, enc_inception4])
    dec_inception4 = conv_block(dec_concat4)
    #print("level 4 DEc",dec_inception4.shape)

    # Level 3
    dec_upconv3 = Conv3DTranspose(filters=256, kernel_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(dec_inception4)
    dec_concat3 = Concatenate(axis=-1)([dec_upconv3, enc_inception3])
    dec_inception3 = conv_block(dec_concat3)

    # Level 2
    dec_upconv2 = Conv3DTranspose(filters=128, kernel_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(dec_inception3)
    dec_concat2 = Concatenate(axis=-1)([dec_upconv2, enc_inception2])
    dec_inception2 = conv_block(dec_concat2)

    # Level 1
    dec_upconv1 = Conv3DTranspose(filters=64, kernel_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(dec_inception2)
    dec_concat1 = Concatenate(axis=-1)([dec_upconv1, enc_inception1])
    dec_inception1 = conv_block(dec_concat1)

    # Output
    output = Conv3D(filters=4, kernel_size=(1, 1, 1), activation='softmax')(dec_inception1)

    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# buiuding the model with the shape of (128, 128, 128, 4)
input_shape = (128, 128, 128, 4) # Adjust the input shape according to data
model = attention_inception_unet(input_shape)

print(model.input)

print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 128, 4), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 128, 4), dtype=tf.float32, name=None), name='conv3d_51/Softmax:0', description="created by layer 'conv3d_51'")

# %%
# printing the summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 128, 4)]   0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 128, 1)     5         ['input_1[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 128, 1)     5         ['input_1[0][0]']
#
#  multiply (Multiply)         (None, 128, 128, 128, 1)     0         ['conv3d[0][0]',
#                                                                      'conv3d_1[0][0]']
#
#  reshape (Reshape)           (None, 2097152)              0         ['multiply[0][0]']
#
#  activation (Activation)     (None, 2097152)              0         ['reshape[0][0]']
#
#  conv3d_2 (Conv3D)           (None, 128, 128, 128, 4)     20        ['input_1[0][0]']
#
#  reshape_1 (Reshape)         (None, 128, 128, 128, 1)     0         ['activation[0][0]']
#
#  multiply_1 (Multiply)       (None, 128, 128, 128, 4)     0         ['conv3d_2[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  conv3d_4 (Conv3D)           (None, 128, 128, 128, 32)    160       ['multiply_1[0][0]']
#
#  conv3d_6 (Conv3D)           (None, 128, 128, 128, 32)    160       ['multiply_1[0][0]']
#
#  max_pooling3d (MaxPooling3  (None, 128, 128, 128, 4)     0         ['multiply_1[0][0]']
#  D)
#
#  conv3d_3 (Conv3D)           (None, 128, 128, 128, 32)    160       ['multiply_1[0][0]']
#
#  conv3d_5 (Conv3D)           (None, 128, 128, 128, 32)    27680     ['conv3d_4[0][0]']
#
#  conv3d_7 (Conv3D)           (None, 128, 128, 128, 32)    128032    ['conv3d_6[0][0]']
#
#  conv3d_8 (Conv3D)           (None, 128, 128, 128, 32)    160       ['max_pooling3d[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 128, 128, 128)   0         ['conv3d_3[0][0]',
#                                                                      'conv3d_5[0][0]',
#                                                                      'conv3d_7[0][0]',
#                                                                      'conv3d_8[0][0]']
#
#  max_pooling3d_1 (MaxPoolin  (None, 64, 64, 64, 128)      0         ['concatenate[0][0]']
#  g3D)
#
#  conv3d_9 (Conv3D)           (None, 64, 64, 64, 1)        129       ['max_pooling3d_1[0][0]']
#
#  conv3d_10 (Conv3D)          (None, 64, 64, 64, 1)        129       ['max_pooling3d_1[0][0]']
#
#  multiply_2 (Multiply)       (None, 64, 64, 64, 1)        0         ['conv3d_9[0][0]',
#                                                                      'conv3d_10[0][0]']
#
#  reshape_2 (Reshape)         (None, 262144)               0         ['multiply_2[0][0]']
#
#  activation_1 (Activation)   (None, 262144)               0         ['reshape_2[0][0]']
#
#  conv3d_11 (Conv3D)          (None, 64, 64, 64, 128)      16512     ['max_pooling3d_1[0][0]']
#
#  reshape_3 (Reshape)         (None, 64, 64, 64, 1)        0         ['activation_1[0][0]']
#
#  multiply_3 (Multiply)       (None, 64, 64, 64, 128)      0         ['conv3d_11[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  conv3d_13 (Conv3D)          (None, 64, 64, 64, 32)       4128      ['multiply_3[0][0]']
#
#  conv3d_15 (Conv3D)          (None, 64, 64, 64, 32)       4128      ['multiply_3[0][0]']
#
#  max_pooling3d_2 (MaxPoolin  (None, 64, 64, 64, 128)      0         ['multiply_3[0][0]']
#  g3D)
#
#  conv3d_12 (Conv3D)          (None, 64, 64, 64, 32)       4128      ['multiply_3[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 64, 64, 64, 32)       27680     ['conv3d_13[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 64, 64, 64, 32)       128032    ['conv3d_15[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 64, 64, 64, 32)       4128      ['max_pooling3d_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 64, 128)      0         ['conv3d_12[0][0]',
#  )                                                                   'conv3d_14[0][0]',
#                                                                      'conv3d_16[0][0]',
#                                                                      'conv3d_17[0][0]']
#
#  max_pooling3d_3 (MaxPoolin  (None, 32, 32, 32, 128)      0         ['concatenate_1[0][0]']
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 32, 32, 32, 1)        129       ['max_pooling3d_3[0][0]']
#
#  conv3d_19 (Conv3D)          (None, 32, 32, 32, 1)        129       ['max_pooling3d_3[0][0]']
#
#  multiply_4 (Multiply)       (None, 32, 32, 32, 1)        0         ['conv3d_18[0][0]',
#                                                                      'conv3d_19[0][0]']
#
#  reshape_4 (Reshape)         (None, 32768)                0         ['multiply_4[0][0]']
#
#  activation_2 (Activation)   (None, 32768)                0         ['reshape_4[0][0]']
#
#  conv3d_20 (Conv3D)          (None, 32, 32, 32, 128)      16512     ['max_pooling3d_3[0][0]']
#
#  reshape_5 (Reshape)         (None, 32, 32, 32, 1)        0         ['activation_2[0][0]']
#
#  multiply_5 (Multiply)       (None, 32, 32, 32, 128)      0         ['conv3d_20[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  conv3d_22 (Conv3D)          (None, 32, 32, 32, 32)       4128      ['multiply_5[0][0]']
#
#  conv3d_24 (Conv3D)          (None, 32, 32, 32, 32)       4128      ['multiply_5[0][0]']
#
#  max_pooling3d_4 (MaxPoolin  (None, 32, 32, 32, 128)      0         ['multiply_5[0][0]']
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 32, 32, 32, 32)       4128      ['multiply_5[0][0]']
#
#  conv3d_23 (Conv3D)          (None, 32, 32, 32, 32)       27680     ['conv3d_22[0][0]']
#
#  conv3d_25 (Conv3D)          (None, 32, 32, 32, 32)       128032    ['conv3d_24[0][0]']
#
#  conv3d_26 (Conv3D)          (None, 32, 32, 32, 32)       4128      ['max_pooling3d_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 32, 128)      0         ['conv3d_21[0][0]',
#  )                                                                   'conv3d_23[0][0]',
#                                                                      'conv3d_25[0][0]',
#                                                                      'conv3d_26[0][0]']
#
#  max_pooling3d_5 (MaxPoolin  (None, 16, 16, 16, 128)      0         ['concatenate_2[0][0]']
#  g3D)
#
#  conv3d_27 (Conv3D)          (None, 16, 16, 16, 1)        129       ['max_pooling3d_5[0][0]']
#
#  conv3d_28 (Conv3D)          (None, 16, 16, 16, 1)        129       ['max_pooling3d_5[0][0]']
#
#  multiply_6 (Multiply)       (None, 16, 16, 16, 1)        0         ['conv3d_27[0][0]',
#                                                                      'conv3d_28[0][0]']
#
#  reshape_6 (Reshape)         (None, 4096)                 0         ['multiply_6[0][0]']
#
#  activation_3 (Activation)   (None, 4096)                 0         ['reshape_6[0][0]']
#
#  conv3d_29 (Conv3D)          (None, 16, 16, 16, 128)      16512     ['max_pooling3d_5[0][0]']
#
#  reshape_7 (Reshape)         (None, 16, 16, 16, 1)        0         ['activation_3[0][0]']
#
#  multiply_7 (Multiply)       (None, 16, 16, 16, 128)      0         ['conv3d_29[0][0]',
#                                                                      'reshape_7[0][0]']
#
#  conv3d_31 (Conv3D)          (None, 16, 16, 16, 32)       4128      ['multiply_7[0][0]']
#
#  conv3d_33 (Conv3D)          (None, 16, 16, 16, 32)       4128      ['multiply_7[0][0]']
#
#  max_pooling3d_6 (MaxPoolin  (None, 16, 16, 16, 128)      0         ['multiply_7[0][0]']
#  g3D)
#
#  conv3d_30 (Conv3D)          (None, 16, 16, 16, 32)       4128      ['multiply_7[0][0]']
#
#  conv3d_32 (Conv3D)          (None, 16, 16, 16, 32)       27680     ['conv3d_31[0][0]']
#
#  conv3d_34 (Conv3D)          (None, 16, 16, 16, 32)       128032    ['conv3d_33[0][0]']
#
#  conv3d_35 (Conv3D)          (None, 16, 16, 16, 32)       4128      ['max_pooling3d_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 16, 16, 16, 128)      0         ['conv3d_30[0][0]',
#  )                                                                   'conv3d_32[0][0]',
#                                                                      'conv3d_34[0][0]',
#                                                                      'conv3d_35[0][0]']
#
#  max_pooling3d_7 (MaxPoolin  (None, 8, 8, 8, 128)         0         ['concatenate_3[0][0]']
#  g3D)
#
#  conv3d_36 (Conv3D)          (None, 8, 8, 8, 1024)        3539968   ['max_pooling3d_7[0][0]']
#
#  conv3d_38 (Conv3D)          (None, 8, 8, 8, 32)          32800     ['conv3d_36[0][0]']
#
#  conv3d_40 (Conv3D)          (None, 8, 8, 8, 32)          32800     ['conv3d_36[0][0]']
#
#  max_pooling3d_8 (MaxPoolin  (None, 8, 8, 8, 1024)        0         ['conv3d_36[0][0]']
#  g3D)
#
#  conv3d_37 (Conv3D)          (None, 8, 8, 8, 32)          32800     ['conv3d_36[0][0]']
#
#  conv3d_39 (Conv3D)          (None, 8, 8, 8, 32)          27680     ['conv3d_38[0][0]']
#
#  conv3d_41 (Conv3D)          (None, 8, 8, 8, 32)          128032    ['conv3d_40[0][0]']
#
#  conv3d_42 (Conv3D)          (None, 8, 8, 8, 32)          32800     ['max_pooling3d_8[0][0]']
#
#  concatenate_4 (Concatenate  (None, 8, 8, 8, 128)         0         ['conv3d_37[0][0]',
#  )                                                                   'conv3d_39[0][0]',
#                                                                      'conv3d_41[0][0]',
#                                                                      'conv3d_42[0][0]']
#
#  conv3d_transpose (Conv3DTr  (None, 16, 16, 16, 512)      524800    ['concatenate_4[0][0]']
#  anspose)
#
#  concatenate_5 (Concatenate  (None, 16, 16, 16, 640)      0         ['conv3d_transpose[0][0]',
#  )                                                                   'concatenate_3[0][0]']
#
#  conv3d_43 (Conv3D)          (None, 16, 16, 16, 32)       552992    ['concatenate_5[0][0]']
#
#  batch_normalization (Batch  (None, 16, 16, 16, 32)       128       ['conv3d_43[0][0]']
#  Normalization)
#
#  activation_4 (Activation)   (None, 16, 16, 16, 32)       0         ['batch_normalization[0][0]']
#
#  conv3d_44 (Conv3D)          (None, 16, 16, 16, 32)       27680     ['activation_4[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 16, 32)       128       ['conv3d_44[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 16, 32)       0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv3d_transpose_1 (Conv3D  (None, 32, 32, 32, 256)      65792     ['activation_5[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 32, 32, 32, 384)      0         ['conv3d_transpose_1[0][0]',
#  )                                                                   'concatenate_2[0][0]']
#
#  conv3d_45 (Conv3D)          (None, 32, 32, 32, 32)       331808    ['concatenate_6[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 32, 32)       128       ['conv3d_45[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 32, 32)       0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv3d_46 (Conv3D)          (None, 32, 32, 32, 32)       27680     ['activation_6[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 32, 32)       128       ['conv3d_46[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 32, 32)       0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv3d_transpose_2 (Conv3D  (None, 64, 64, 64, 128)      32896     ['activation_7[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 64, 64, 64, 256)      0         ['conv3d_transpose_2[0][0]',
#  )                                                                   'concatenate_1[0][0]']
#
#  conv3d_47 (Conv3D)          (None, 64, 64, 64, 32)       221216    ['concatenate_7[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 64, 32)       128       ['conv3d_47[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 64, 64, 64, 32)       0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv3d_48 (Conv3D)          (None, 64, 64, 64, 32)       27680     ['activation_8[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 64, 32)       128       ['conv3d_48[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 64, 64, 64, 32)       0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv3d_transpose_3 (Conv3D  (None, 128, 128, 128, 64)    16448     ['activation_9[0][0]']
#  Transpose)
#
#  concatenate_8 (Concatenate  (None, 128, 128, 128, 192)   0         ['conv3d_transpose_3[0][0]',
#  )                                                                   'concatenate[0][0]']
#
#  conv3d_49 (Conv3D)          (None, 128, 128, 128, 32)    165920    ['concatenate_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 128, 128, 32)    128       ['conv3d_49[0][0]']
#  chNormalization)
#
#  activation_10 (Activation)  (None, 128, 128, 128, 32)    0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv3d_50 (Conv3D)          (None, 128, 128, 128, 32)    27680     ['activation_10[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 128, 128, 32)    128       ['conv3d_50[0][0]']
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128, 128, 128, 32)    0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv3d_51 (Conv3D)          (None, 128, 128, 128, 4)     132       ['activation_11[0][0]']
#
# ==================================================================================================
# Total params: 6573992 (25.08 MB)
# Trainable params: 6573480 (25.08 MB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________
